# %% [markdown]
# 🧪 Lesson 4: Summarize Read Counts with featureCounts
# 🎯 Goal - Use featureCounts to count how many reads map to each gene in Clostridium autoethanogenum.
#
# 📁 Prerequisites Recap:
# You have a bam_files/ folder with aligned .bam files.
# You have the Clostridium autoethanogenum genome annotation .gtf file downloaded from NCBI here.
#
# ✅ STEP 1:  the Annotation File
# Download and unzip the GTF if not already done:

# %%
mkdir -p reference
cd reference
wget https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/484/505/GCF_000484505.2_ASM48450v2/GCF_000484505.2_ASM48450v2_genomic.gtf.gz
gunzip GCF_000484505.2_ASM48450v2_genomic.gtf.gz
cd ..

# %% [markdown]
# ✅ STEP 2: Count Reads Using featureCounts
# Here’s the optimized script to run featureCounts on all BAM files at once, using 8 threads:

# %%
#!/bin/bash
# File: count_reads_featureCounts.sh
# Location: rnaseq_project folder
# Description: Count gene-level reads from BAMs

mkdir -p counts

featureCounts \
  -T 8 \
  -p \
  -t gene \
  -g gene_id \
  -a reference/GCF_000484505.2_ASM48450v2_genomic.gtf \
  -o counts/gene_counts.txt \
  bam_files/*.bam

# %% [markdown]
# 🧠 Explanation:
#
# -T 8: use 8 threads
# -p: paired-end reads
# -t gene: look for “gene” features in the GTF
# -g gene_id: use gene_id as count grouping
# -a: path to annotation
# -o: output file
# bam_files/*.bam: input BAMs
#
# Make it executable and run the script:

# %%
# !chmod +x count_reads_featureCounts.sh
# !bash count_reads_featureCounts.sh
# Out:
#         ==========     _____ _    _ ____  _____  ______          _____
#         =====         / ____| |  | |  _ \|  __ \|  ____|   /\   |  __ \
#           =====      | (___ | |  | | |_) | |__) | |__     /  \  | |  | |
#             ====      \___ \| |  | |  _ <|  _  /|  __|   / /\ \ | |  | |
#               ====    ____) | |__| | |_) | | \ \| |____ / ____ \| |__| |
#         ==========   |_____/ \____/|____/|_|  \_\______/_/    \_\_____/
# 	  v2.1.1
#
# //========================== featureCounts setting ===========================\\
# ||                                                                            ||
# ||             Input files : 15 BAM files                                     ||
# ||                                                                            ||
# ||                           SRR23426208.bam                                  ||
# ||                           SRR23426209.bam                                  ||
# ||                           SRR23426210.bam                                  ||
# ||                           SRR23426211.bam                                  ||
# ||                           SRR23426212.bam                                  ||
# ||                           SRR23426213.bam                                  ||
# ||                           SRR23426214.bam                                  ||
# ||                           SRR23426215.bam                                  ||
# ||                           SRR23426216.bam                                  ||
# ||                           SRR23426217.bam                                  ||
# ||                           SRR23426218.bam                                  ||
# ||                           SRR23426219.bam                                  ||
# ||                           SRR23426220.bam                                  ||
# ||                           SRR23426221.bam                                  ||
# ||                           SRR23426222.bam                                  ||
# ||                                                                            ||
# ||             Output file : gene_counts.txt                                  ||
# ||                 Summary : gene_counts.txt.summary                          ||
# ||              Paired-end : yes                                              ||
# ||        Count read pairs : no                                               ||
# ||              Annotation : GCF_000484505.2_ASM48450v2_genomic.gtf (GTF)     ||
# ||      Dir for temp files : counts                                           ||
# ||                                                                            ||
# ||                 Threads : 8                                                ||
# ||                   Level : meta-feature level                               ||
# ||      Multimapping reads : not counted                                      ||
# || Multi-overlapping reads : not counted                                      ||
# ||   Min overlapping bases : 1                                                ||
# ||                                                                            ||
# \\============================================================================//
#
# //================================= Running ==================================\\
# ||                                                                            ||
# || Load annotation file GCF_000484505.2_ASM48450v2_genomic.gtf ...            ||
# ||    Features : 4132                                                         ||
# ||    Meta-features : 4132                                                    ||
# ||    Chromosomes/contigs : 2                                                 ||
# ||                                                                            ||
# || Process BAM file SRR23426208.bam...                                        ||
# ||    Paired-end reads are included.                                          ||
# ||    The reads are assigned on the single-end mode.                          ||
# ||    Total alignments : 34067178                                             ||
# ||    Successfully assigned alignments : 11768690 (34.5%)                     ||
# ||    Running time : 0.11 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR23426209.bam...                                        ||
# ||    Paired-end reads are included.                                          ||
# ||    The reads are assigned on the single-end mode.                          ||
# ||    Total alignments : 36504522                                             ||
# ||    Successfully assigned alignments : 11188388 (30.6%)                     ||
# ||    Running time : 0.13 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR23426210.bam...                                        ||
# ||    Paired-end reads are included.                                          ||
# ||    The reads are assigned on the single-end mode.                          ||
# ||    Total alignments : 35243713                                             ||
# ||    Successfully assigned alignments : 13597057 (38.6%)                     ||
# ||    Running time : 0.15 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR23426211.bam...                                        ||
# ||    Paired-end reads are included.                                          ||
# ||    The reads are assigned on the single-end mode.                          ||
# ||    Total alignments : 30833214                                             ||
# ||    Successfully assigned alignments : 11224849 (36.4%)                     ||
# ||    Running time : 0.16 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR23426212.bam...                                        ||
# ||    Paired-end reads are included.                                          ||
# ||    The reads are assigned on the single-end mode.                          ||
# ||    Total alignments : 37065658                                             ||
# ||    Successfully assigned alignments : 10693347 (28.8%)                     ||
# ||    Running time : 0.16 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR23426213.bam...                                        ||
# ||    Paired-end reads are included.                                          ||
# ||    The reads are assigned on the single-end mode.                          ||
# ||    Total alignments : 37107215                                             ||
# ||    Successfully assigned alignments : 13431608 (36.2%)                     ||
# ||    Running time : 0.17 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR23426214.bam...                                        ||
# ||    Paired-end reads are included.                                          ||
# ||    The reads are assigned on the single-end mode.                          ||
# ||    Total alignments : 31128714                                             ||
# ||    Successfully assigned alignments : 11563293 (37.1%)                     ||
# ||    Running time : 0.14 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR23426215.bam...                                        ||
# ||    Paired-end reads are included.                                          ||
# ||    The reads are assigned on the single-end mode.                          ||
# ||    Total alignments : 33482254                                             ||
# ||    Successfully assigned alignments : 10436464 (31.2%)                     ||
# ||    Running time : 0.15 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR23426216.bam...                                        ||
# ||    Paired-end reads are included.                                          ||
# ||    The reads are assigned on the single-end mode.                          ||
# ||    Total alignments : 32891356                                             ||
# ||    Successfully assigned alignments : 11349676 (34.5%)                     ||
# ||    Running time : 0.16 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR23426217.bam...                                        ||
# ||    Paired-end reads are included.                                          ||
# ||    The reads are assigned on the single-end mode.                          ||
# ||    Total alignments : 36836211                                             ||
# ||    Successfully assigned alignments : 12452057 (33.8%)                     ||
# ||    Running time : 0.15 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR23426218.bam...                                        ||
# ||    Paired-end reads are included.                                          ||
# ||    The reads are assigned on the single-end mode.                          ||
# ||    Total alignments : 36692234                                             ||
# ||    Successfully assigned alignments : 15031154 (41.0%)                     ||
# ||    Running time : 0.17 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR23426219.bam...                                        ||
# ||    Paired-end reads are included.                                          ||
# ||    The reads are assigned on the single-end mode.                          ||
# ||    Total alignments : 36980048                                             ||
# ||    Successfully assigned alignments : 13330183 (36.0%)                     ||
# ||    Running time : 0.16 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR23426220.bam...                                        ||
# ||    Paired-end reads are included.                                          ||
# ||    The reads are assigned on the single-end mode.                          ||
# ||    Total alignments : 31731231                                             ||
# ||    Successfully assigned alignments : 11310556 (35.6%)                     ||
# ||    Running time : 0.13 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR23426221.bam...                                        ||
# ||    Paired-end reads are included.                                          ||
# ||    The reads are assigned on the single-end mode.                          ||
# ||    Total alignments : 35519694                                             ||
# ||    Successfully assigned alignments : 11284451 (31.8%)                     ||
# ||    Running time : 0.16 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR23426222.bam...                                        ||
# ||    Paired-end reads are included.                                          ||
# ||    The reads are assigned on the single-end mode.                          ||
# ||    Total alignments : 36478086                                             ||
# ||    Successfully assigned alignments : 12250831 (33.6%)                     ||
# ||    Running time : 0.15 minutes                                             ||
# ||                                                                            ||
# || Write the final count table.                                               ||
# || Write the read assignment summary.                                         ||
# ||                                                                            ||
# || Summary of counting results can be found in file "counts/gene_counts.txt.  ||
# || summary"                                                                   ||
# ||                                                                            ||
# \\============================================================================//

# %% [markdown]
# ✅ STEP 3: Inspect Output
#
# You should now have:
#
# counts/gene_counts.txt: actual count matrix (tab-delimited)
#
# counts/gene_counts.txt.summary: summary report per BAM
#
# Check the matrix:

# %%
# !head counts/gene_counts.txt
# Out:
# # Program:featureCounts v2.1.1; Command:"featureCounts" "-T" "8" "-p" "-t" "gene" "-g" "gene_id" "-a" "reference/GCF_000484505.2_ASM48450v2_genomic.gtf" "-o" "counts/gene_counts.txt" "bam_files/SRR23426208.bam" "bam_files/SRR23426209.bam" "bam_files/SRR23426210.bam" "bam_files/SRR23426211.bam" "bam_files/SRR23426212.bam" "bam_files/SRR23426213.bam" "bam_files/SRR23426214.bam" "bam_files/SRR23426215.bam" "bam_files/SRR23426216.bam" "bam_files/SRR23426217.bam" "bam_files/SRR23426218.bam" "bam_files/SRR23426219.bam" "bam_files/SRR23426220.bam" "bam_files/SRR23426221.bam" "bam_files/SRR23426222.bam"
# Geneid	Chr	Start	End	Strand	Length	bam_files/SRR23426208.bam	bam_files/SRR23426209.bam	bam_files/SRR23426210.bam	bam_files/SRR23426211.bam	bam_files/SRR23426212.bam	bam_files/SRR23426213.bam	bam_files/SRR23426214.bam	bam_files/SRR23426215.bam	bam_files/SRR23426216.bam	bam_files/SRR23426217.bam	bam_files/SRR23426218.bam	bam_files/SRR23426219.bam	bam_files/SRR23426220.bam	bam_files/SRR23426221.bam	bam_files/SRR23426222.bam
# CAETHG_RS00005	NC_022592.1	79	285	+	207	236	199	296	222	193	317	283	286	244	177	358	129	164	252	220
# CAETHG_RS00010	NC_022592.1	524	781	-	258	9	89	12	56	210	125	21	42	41	673	1117	523	197	138	36
# CAETHG_RS00015	NC_022592.1	789	1250	-	462	12	106	20	37	172	81	10	47	29	706	1098	630	141	130	31
# CAETHG_RS00020	NC_022592.1	1366	2340	+	975	988	985	1203	730	597	906	932	686	1087	524	597	622	773	697	1072
# CAETHG_RS00025	NC_022592.1	2384	3609	+	1226	729	848	1227	791	654	808	909	689	1044	499	520	720	802	686	1141
# CAETHG_RS00030	NC_022592.1	3633	6290	+	2658	1379	1566	2559	1749	1316	1771	1733	1563	1927	1370	1850	1526	1612	1869	2360
# CAETHG_RS00035	NC_022592.1	6496	7722	+	1227	224	180	637	510	209	254	1098	425	142	415	493	398	236	380	488
# CAETHG_RS00040	NC_022592.1	7752	9257	+	1506	297	268	993	704	431	493	1270	676	243	1044	1136	886	576	764	860

# %% [markdown]
# #🔁 STEP 4: Git Update - Let’s save your work so far to GitHub.
# #
# #run in motherfolder (BifrostOmics)
# git add rnaseq_project/counts/
# git add rnaseq_project/reference/GCF_000484505.2_ASM48450v2_genomic.gtf
# git commit -m "Lesson 4 complete: Gene counts generated with featureCounts"
# git push
